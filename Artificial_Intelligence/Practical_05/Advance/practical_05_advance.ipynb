# %% [markdown]
# # ❌ Practical 05 - Advanced Minimax Tic-Tac-Toe
#
# This notebook builds an interactive **Tic-Tac-Toe Game** driven by the **Minimax Algorithm**. The AI evaluates empty squares and prints state score projections before moving.

# %% [markdown]
# ### 1. Import and Configuration

# %%
import matplotlib.pyplot as plt
from IPython.display import clear_output
import time
import math

# Board representation
board = [[' ' for _ in range(3)] for _ in range(3)]
colors = {'X': 'red', 'O': 'blue', ' ': 'white'}

# %% [markdown]
# ### 2. Board Visualization Function

# %%
def plot_board(b, evals=None):
    clear_output(wait=True)
    fig, ax = plt.subplots(figsize=(5,5))
    
    # Draw symbols
    for i in range(3):
        for j in range(3):
            ax.text(j+0.5, 2-i+0.5, b[i][j], fontsize=40, ha='center', va='center', color=colors[b[i][j]])
    
    # Draw evaluation scores
    if evals:
        for (i,j), score in evals.items():
            ax.text(j+0.5, 2-i+0.2, f"{score}", fontsize=12, ha='center', va='center', color='green')

    ax.set_xlim(0,3)
    ax.set_ylim(0,3)
    ax.set_xticks(range(4))
    ax.set_yticks(range(4))
    ax.grid(True)
    plt.show()
    time.sleep(0.8)

# %% [markdown]
# ### 3. Minimax Decision Rules

# %%
def is_moves_left(b):
    return any(cell == ' ' for row in b for cell in row)

def evaluate(b):
    for i in range(3):
        if b[i][0] == b[i][1] == b[i][2] != ' ':
            return 10 if b[i][0] == 'X' else -10
        if b[0][i] == b[1][i] == b[2][i] != ' ':
            return 10 if b[0][i] == 'X' else -10
    if b[0][0] == b[1][1] == b[2][2] != ' ':
        return 10 if b[0][0] == 'X' else -10
    if b[0][2] == b[1][1] == b[2][0] != ' ':
        return 10 if b[0][2] == 'X' else -10
    return 0

def minimax(b, depth, is_max):
    score = evaluate(b)
    if score != 0 or not is_moves_left(b):
        return score

    if is_max:
        best = -math.inf
        for i in range(3):
            for j in range(3):
                if b[i][j] == ' ':
                    b[i][j] = 'X'
                    best = max(best, minimax(b, depth+1, False))
                    b[i][j] = ' '
        return best
    else:
        best = math.inf
        for i in range(3):
            for j in range(3):
                if b[i][j] == ' ':
                    b[i][j] = 'O'
                    best = min(best, minimax(b, depth+1, True))
                    b[i][j] = ' '
        return best

# %% [markdown]
# ### 4. Find Best Move Wrapper

# %%
def find_best_move(b):
    best_val = -math.inf
    best_move = (-1,-1)
    evals = {}
    
    for i in range(3):
        for j in range(3):
            if b[i][j] == ' ':
                b[i][j] = 'X'
                move_val = minimax(b, 0, False)
                b[i][j] = ' '
                evals[(i,j)] = move_val  # store evaluation score
                if move_val > best_val:
                    best_val = move_val
                    best_move = (i,j)
    plot_board(b, evals)  # Show evaluation values before AI picks
    return best_move

# %% [markdown]
# ### 5. Play Loop
#
# To start playing against the AI, uncomment the final function call.

# %%
def play_game():
    # reset board
    global board
    board = [[' ' for _ in range(3)] for _ in range(3)]
    plot_board(board)
    
    while True:
        if not is_moves_left(board) or evaluate(board) != 0:
            break

        # Player O move
        row = int(input("Enter your move (row 0-2): "))
        col = int(input("Enter your move (col 0-2): "))
        if board[row][col] != ' ':
            print("Invalid move. Try again.")
            continue
        board[row][col] = 'O'
        plot_board(board)

        # AI X move
        if is_moves_left(board) and evaluate(board) == 0:
            ai_move = find_best_move(board)
            board[ai_move[0]][ai_move[1]] = 'X'
            print(f"AI moves at {ai_move}")
            plot_board(board)

    score = evaluate(board)
    if score == 10:
        print("AI Wins!")
    elif score == -10:
        print("You Win!")
    else:
        print("It's a Draw!")

# play_game()  # Uncomment to play
